# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from sklearn.model_selection import KFold
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
df = pd.read_csv('/data/train.csv')

# %%
df
# Out:
#                                         StudyInstanceUID  ETT - Abnormal  \
# 0      1.2.826.0.1.3680043.8.498.26697628953273228189...               0
# 1      1.2.826.0.1.3680043.8.498.46302891597398758759...               0
# 2      1.2.826.0.1.3680043.8.498.23819260719748494858...               0
# 3      1.2.826.0.1.3680043.8.498.68286643202323212801...               0
# 4      1.2.826.0.1.3680043.8.498.10050203009225938259...               0
# ...                                                  ...             ...
# 30078  1.2.826.0.1.3680043.8.498.74257566841157531124...               0
# 30079  1.2.826.0.1.3680043.8.498.46510939987173529969...               0
# 30080  1.2.826.0.1.3680043.8.498.43173270582850645437...               0
# 30081  1.2.826.0.1.3680043.8.498.95092491950130838685...               0
# 30082  1.2.826.0.1.3680043.8.498.99518162226171269731...               0
#
#        ETT - Borderline  ETT - Normal  NGT - Abnormal  NGT - Borderline  \
# ...

# %%
patient_id = df.PatientID.value_counts().index

# %%
df.PatientID.isin(patient_id[:2])
# Out:
# 339

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=613)

df["cv"] = -1

for i, (_, val_index) in enumerate(kfold.split(patient_id)):
    df.loc[df.PatientID.isin(patient_id[val_index]), "cv"] = i

# %%
df
# Out:
#                                         StudyInstanceUID  ETT - Abnormal  \
# 0      1.2.826.0.1.3680043.8.498.26697628953273228189...               0
# 1      1.2.826.0.1.3680043.8.498.46302891597398758759...               0
# 2      1.2.826.0.1.3680043.8.498.23819260719748494858...               0
# 3      1.2.826.0.1.3680043.8.498.68286643202323212801...               0
# 4      1.2.826.0.1.3680043.8.498.10050203009225938259...               0
# ...                                                  ...             ...
# 30078  1.2.826.0.1.3680043.8.498.74257566841157531124...               0
# 30079  1.2.826.0.1.3680043.8.498.46510939987173529969...               0
# 30080  1.2.826.0.1.3680043.8.498.43173270582850645437...               0
# 30081  1.2.826.0.1.3680043.8.498.95092491950130838685...               0
# 30082  1.2.826.0.1.3680043.8.498.99518162226171269731...               0
#
#        ETT - Borderline  ETT - Normal  NGT - Abnormal  NGT - Borderline  \
# ...

# %%
df.cv.value_counts()
# Out:
# 1    6278
# 3    6162
# 4    5984
# 2    5971
# 0    5688
# Name: cv, dtype: int64

# %%
for j in range(11):
    plt.figure(figsize=(20, 4))
    for i in range(5):
        plt.subplot(1, 5, i+1)
        sns.histplot(df[df.cv == i].iloc[:, 1+j])
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
df.StudyInstanceUID[0]
# Out:
# '1.2.826.0.1.3680043.8.498.26697628953273228189375557799582420561'

# %%
df["img_path"] = [f"/data/train512/{i}.jpg" for i in df.StudyInstanceUID]

# %%
df.to_csv('/data/df_train.csv', index=False)

# %%
df.columns
# Out:
# Index(['StudyInstanceUID', 'ETT - Abnormal', 'ETT - Borderline',
#        'ETT - Normal', 'NGT - Abnormal', 'NGT - Borderline',
#        'NGT - Incompletely Imaged', 'NGT - Normal', 'CVC - Abnormal',
#        'CVC - Borderline', 'CVC - Normal', 'Swan Ganz Catheter Present',
#        'PatientID', 'cv'],
#       dtype='object')

# %%
df.iloc[9][['ETT - Abnormal', 'ETT - Borderline',
       'ETT - Normal', 'NGT - Abnormal', 'NGT - Borderline',
       'NGT - Incompletely Imaged', 'NGT - Normal', 'CVC - Abnormal',
       'CVC - Borderline', 'CVC - Normal', 'Swan Ganz Catheter Present']].values
# Out:
# array([0, 1, 0, 0, 0, 0, 1, 0, 0, 1, 0], dtype=object)

# %%
df.iloc[9][['ETT - Abnormal', 'ETT - Borderline',
       'ETT - Normal', 'NGT - Abnormal', 'NGT - Borderline',
       'NGT - Incompletely Imaged', 'NGT - Normal', 'CVC - Abnormal',
       'CVC - Borderline', 'CVC - Normal', 'Swan Ganz Catheter Present']].values.shape
# Out:
# (11,)
